# %%
file = open("test.txt", "r")

for i in file:
    print(i)
# Out:
# Hi
#
# I'm naveen

# %%
file = open("test.txt", "r")

print(file.read())
# Out:
# H

# %%
file = open("test.txt", "r")

print(file.readlines())
# Out:
# ['Hi\n', "I'm naveen"]

# %%
file = open("test.txt", "r+")

file.write("He is a good person \n")
file.write("This is the next line")

file.seek(0)
print(file.read())
